# %% [markdown]
# ## file path

# %%
import os
cwd=os.getcwd()
print(cwd)
# Out:
# c:\Users\HP\Desktop\F_DA\python\6-file handling

# %%
## create a new directory
new_dir = 'new_directory'
os.mkdir(new_dir)
print(f"Directory '{new_dir}' created successfully.")
# Out:
# Directory 'new_directory' created successfully.

# %%
## listing files and directories

items = os.listdir('.')
print(items)
# Out:
# ['6.1-filesoperations.ipynb', '6.2-filepath.ipynb', 'copy_example.txt', 'example.bin', 'example.txt', 'new_directory']

# %%
dir_name = 'new_directory'
file_name = 'example.txt'
file_path = os.path.join(dir_name, file_name)
print(file_path)
# Out:
# new_directory\example.txt

# %%
dir_name="floder"
file_name="example.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\HP\Desktop\F_DA\python\6-file handling\floder\example.txt

# %%
path ='example.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
# Out:
# The file 'example.txt' exists.

# %%
## checking file 

import os 

path = 'example.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
# Out:
# The file 'example.txt' exists.

# %%
## getting the absoute path of a file
file_name = 'example.txt'
abs_path = os.path.abspath(file_name)
print(f"The absolute path of '{file_name}' is: {abs_path}")
# Out:
# The absolute path of 'example.txt' is: c:\Users\HP\Desktop\F_DA\python\6-file handling\example.txt
