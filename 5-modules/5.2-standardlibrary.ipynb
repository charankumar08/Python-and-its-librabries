# %% [markdown]
# ## standard library

# %%
import array 
arr =array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random

import random 
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 4
# banana

# %%
## file and directory access
import os
print(os.getcwd())
# Out:
# c:\Users\HP\Desktop\F_DA\python\5-modules

# %%
os.mkdir('test_dir')

# %%
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization

import json
data ={
    'name':'cherry', 'age':21
}

json_str =json.dumps(data)
print(json_str)
print(type(json_str))


parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "cherry", "age": 21}
# <class 'str'>
# {'name': 'cherry', 'age': 21}
# <class 'dict'>

# %%
## csv

import csv
with open ('example.csv',mode='w',newline='')as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['cherry',21])

with open ('example.csv',mode='r')as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['cherry', '21']

# %%
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2026-02-27 22:07:58.496916
# 2026-02-26 22:07:58.496916

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1772210370.6744578
# 1772210372.675394

# %%
##regular expression

import re

pattern =r'\d+'
text = 'there are 123 apples 1432'
match =re.search (pattern,text)
print(match.group())
# Out:
# 123
