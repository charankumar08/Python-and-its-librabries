# %%
## python is case sensitive, so the variable name
name = "cherry"
Name = "Charan"

print(name)
print(Name)
# Out:
# cherry
# Charan

# %%
##python Indentation
age = 20
if age > 18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# you are eligible to vote

# %%
## line continuation
a = 10 + 20 + 30 + \
    40 + 50 
print(a)
# Out:
# 150

# %%
## multiple line comment
""" this is for DA course
and this is for python basics"""

# %%
## single line comment
# this is for python basics

# %%
## multiple statement in single line
a = 10; b = 20; c = 30
print(a, b, c)
# Out:
# 10 20 30

# %%
## semnatics in python

age = 20 
print(type(age)) ##age is a variable and 20 is a value


name = "cherry" ## name is a variable and "cherry" is a value
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>
