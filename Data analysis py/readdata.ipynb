# %% [markdown]
# ## Reading data From different sources

# %%
import pandas as pd
from io import StringIO
Data ='{"employee_id": [1, 2, 3, 4, 5], "employee_name": ["John", "Jane", "Doe", "Smith", "Emily"], "department": ["HR", "Finance", "IT", "Marketing", "Sales"]}'
df = pd.read_json(StringIO(Data))
print(df)
# Out:
#    employee_id employee_name department
# 0            1          John         HR
# 1            2          Jane    Finance
# 2            3           Doe         IT
# 3            4         Smith  Marketing
# 4            5         Emily      Sales

# %%
df.to_json()
# Out:
# '{"employee_id":{"0":1,"1":2,"2":3,"3":4,"4":5},"employee_name":{"0":"John","1":"Jane","2":"Doe","3":"Smith","4":"Emily"},"department":{"0":"HR","1":"Finance","2":"IT","3":"Marketing","4":"Sales"}}'

# %%
df.head()
# Out:
#    employee_id employee_name department
# 0            1          John         HR
# 1            2          Jane    Finance
# 2            3           Doe         IT
# 3            4         Smith  Marketing
# 4            5         Emily      Sales

# %%
df.to_json(orient='records')
# Out:
# '[{"employee_id":1,"employee_name":"John","department":"HR"},{"employee_id":2,"employee_name":"Jane","department":"Finance"},{"employee_id":3,"employee_name":"Doe","department":"IT"},{"employee_id":4,"employee_name":"Smith","department":"Marketing"},{"employee_id":5,"employee_name":"Emily","department":"Sales"}]'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee_id":1,"employee_name":"John","department":"HR"},"1":{"employee_id":2,"employee_name":"Jane","department":"Finance"},"2":{"employee_id":3,"employee_name":"Doe","department":"IT"},"3":{"employee_id":4,"employee_name":"Smith","department":"Marketing"},"4":{"employee_id":5,"employee_name":"Emily","department":"Sales"}}'

# %%
df=pd.read_csv("dataa.csv")

# %%
df.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.to_csv("new.csv")

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 6.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.1 MB/s  0:00:00
# ...

# %%
url="https://www.hdfc.bank.in/fixed-deposit/fd-interest-rate"
pd.read_html(url)
pd.read_html(url)[0]
# Out:
#                            Tenor Bucket                 < ₹3 Crore  \
# 0                                   NaN  Interest Rate (per annum)
# 1                           7 - 14 days                      2.75%
# 2                            15-29 days                      2.75%
# 3                            30-45 days                      3.25%
# 4                            46-60 days                      4.25%
# 5                            61-89 days                      4.25%
# 6                   90 days <= 6 months                      4.25%
# 7             6 months 1 day <=9 months                      5.50%
# 8            9 months 1 day to < 1 Year                      5.75%
# 9                 1 Year to < 15 months                      6.25%
# 10             15 months to < 18 months                      6.35%
# 11             18 months to < 21 months                      6.45%
# 12                 21 months to 2 years                      6.45%
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df_excel= pd.read_excel(r"C:\Users\HP\Downloads\TechCode.xlsx")
print(df)
# Out:
#       Issue ID First Name Last Name     ATM ID  \
# 0   0d5ff8ed8d   Fredrick  Thompson      33562
# 1   d9c1547599      Patsy   Sheehan      66722
# 2   e0cb653f42        Jon      Snow       3351
# 3   94803beda8  Alexander     Ramos      37490
# 4   da18217bc3      Verna     Moore      77827
# 5   d146f1ccc1      Megan   Iverson      51428
# 6   045dbe3b7b       Paul     Edson      16252
# 7   d9d1df320a   Danielle      West      98308
# 8     JTXhApOb  Alexander     Ramos      37490
# 9     23a5558b      quick       lab     ABC123
# 10    ac7aa33f     Freeda       NaN  Freeda123
#
#                                    Email                       Symptom  Photo  \
# 0    fredrick.thompson@fakeitcompany.com              ATM wont turn on    NaN
# 1        patsy.sheehan@fakeitcompany.com       Card reader not working    NaN
# 2             jon.snow@fakeitcompany.com                 Broken keypad    NaN
# 3      alexander.ramos@fakeitcompany.com               Low cash supply    NaN
# ...

# %%
# Save the dataframe to a pickle file


# Load it back if needed
df_excel = pd.read_pickle('df_excel.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 5
#       1 # Save the dataframe to a pickle file
#       2
#       3
#       4 # Load it back if needed
# ----> 5 df_excel = pd.read_pickle('df_excel.pkl')
#
# File c:\Users\HP\Desktop\F_DA\python\venv\Lib\site-packages\pandas\io\pickle.py:220, in read_pickle(filepath_or_buffer, compression, storage_options)
#     218 # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     219 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 220 with get_handle(
#     221     filepath_or_buffer,
#     222     "rb",
#     223     compression=compression,
#     224     is_text=False,
#     225     storage_options=storage_options,
#     226 ) as handles:
#     227     # 1) try standard library Pickle
# ...
